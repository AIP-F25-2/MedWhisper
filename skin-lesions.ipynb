# %% [markdown]
# # Skin dermatology
#
# - dataset: https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000?resource=download

# %%
# %pip install --upgrade pip setuptools wheel
# PyTorch (CPU); if you already have torch with CUDA, you can skip this CPU line
# %pip install torch torchvision torchaudio --upgrade
# Vision + metrics deps
# %pip install timm scikit-learn matplotlib pandas opencv-python-headless tqdm seaborn
# Try pytorch-grad-cam first; if not available for your Python, we'll fallback to torchcam
try:
    # %pip install pytorch-grad-cam
    print("Installed pytorch-grad-cam.")
except Exception as e:
    print("Could not install pytorch-grad-cam:", e)
    # %pip install torchcam
    print("Installed torchcam as fallback.")
# Out:
# Requirement already satisfied: pip in c:\users\nitro\anaconda3\lib\site-packages (25.2)
# Requirement already satisfied: setuptools in c:\users\nitro\anaconda3\lib\site-packages (68.2.2)
# Collecting setuptools
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: wheel in c:\users\nitro\anaconda3\lib\site-packages (0.41.2)
# Collecting wheel
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: wheel, setuptools
#
#   Attempting uninstall: wheel
#
#     Found existing installation: wheel 0.41.2
#
#     Uninstalling wheel-0.41.2:
#
#       Successfully uninstalled wheel-0.41.2
#
#    ---------------------------------------- 0/2 [wheel]
#    ---------------------------------------- 0/2 [wheel]
#   Attempting uninstall: setuptools
#    ---------------------------------------- 0/2 [wheel]
#    -------------------- ------------------- 1/2 [setuptools]
#     Found existing installation: setuptools 68.2.2
#    -------------------- ------------------- 1/2 [setuptools]
#     Uninstalling setuptools-68.2.2:
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#       Successfully uninstalled setuptools-68.2.2
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    -------------------- ------------------- 1/2 [setuptools]
#    ---------------------------------------- 2/2 [setuptools]
#
# Successfully installed setuptools-80.9.0 wheel-0.45.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# Requirement already satisfied: torch in c:\users\nitro\anaconda3\lib\site-packages (2.7.1)
# Collecting torch
#   Downloading torch-2.9.0-cp311-cp311-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: torchvision in c:\users\nitro\anaconda3\lib\site-packages (0.22.1)
# Collecting torchvision
#   Downloading torchvision-0.24.0-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: torchaudio in c:\users\nitro\anaconda3\lib\site-packages (2.7.1)
# Collecting torchaudio
#   Downloading torchaudio-2.9.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in c:\users\nitro\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\nitro\anaconda3\lib\site-packages (from torch) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\nitro\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\nitro\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\nitro\anaconda3\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\nitro\anaconda3\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: numpy in c:\users\nitro\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\nitro\anaconda3\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nitro\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nitro\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Downloading torch-2.9.0-cp311-cp311-win_amd64.whl (109.3 MB)
#    ---------------------------------------- 0.0/109.3 MB ? eta -:--:--
#    - -------------------------------------- 3.4/109.3 MB 18.4 MB/s eta 0:00:06
#    -- ------------------------------------- 6.8/109.3 MB 20.0 MB/s eta 0:00:06
#    --- ------------------------------------ 9.2/109.3 MB 14.6 MB/s eta 0:00:07
#    --- ------------------------------------ 10.2/109.3 MB 12.0 MB/s eta 0:00:09
#    --- ------------------------------------ 10.7/109.3 MB 10.7 MB/s eta 0:00:10
#    ---- ----------------------------------- 11.5/109.3 MB 9.0 MB/s eta 0:00:11
#    ---- ----------------------------------- 12.6/109.3 MB 8.5 MB/s eta 0:00:12
#    ---- ----------------------------------- 13.1/109.3 MB 7.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 13.4/109.3 MB 7.4 MB/s eta 0:00:14
#    ----- ---------------------------------- 14.4/109.3 MB 6.8 MB/s eta 0:00:15
#    ----- ---------------------------------- 15.5/109.3 MB 6.7 MB/s eta 0:00:15
#    ----- ----------------------------------
3 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 109.3/109.3 MB 5.2 MB/s  0:00:21
# Downloading torchvision-0.24.0-cp311-cp311-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------- -------------------------- 1.3/4.0 MB 8.4 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 7.5 MB/s  0:00:00
# Downloading torchaudio-2.9.0-cp311-cp311-win_amd64.whl (664 kB)
#    ---------------------------------------- 0.0/664.7 kB ? eta -:--:--
#    ---------------------------------------- 664.7/664.7 kB 8.6 MB/s  0:00:00
# Installing collected packages: torch, torchvision, torchaudio
#
#   Attempting uninstall: torch
#
#     Found existing installation: torch 2.7.1
#
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#     Uninstalling torch-2.7.1:
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#       Successfully uninstalled torch-2.7.1
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#   Attempting uninstall: torchvision
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#     Found existing installation: torchvision 0.22.1
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#     Uninstalling torchvision-0.22.1:
#    ------------- -------------------------- 1/3 [torchvision]
#       Successfully uninstalled torchvision-0.22.1
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#   Attempting uninstall: torchaudio
#    ------------- -------------------------- 1/3 [torchvision]
#     Found existing installation: torchaudio 2.7.1
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#     Uninstalling torchaudio-2.7.1:
#    -------------------------- ------------- 2/3 [torchaudio]
#       Successfully uninstalled torchaudio-2.7.1
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    ---------------------------------------- 3/3 [torchaudio]
#
# Successfully installed torch-2.9.0 torchaudio-2.9.0 torchvision-0.24.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Nitro\anaconda3\Lib\site-packages\~orch'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Nitro\anaconda3\Lib\site-packages\~orchvision'.
#   You can safely remove it manually.
# Requirement already satisfied: timm in c:\users\nitro\anaconda3\lib\site-packages (1.0.20)
# Requirement already satisfied: scikit-learn in c:\users\nitro\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: matplotlib in c:\users\nitro\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: pandas in c:\users\nitro\anaconda3\lib\site-packages (2.1.4)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: tqdm in c:\users\nitro\anaconda3\lib\site-packages (4.65.0)
# Requirement already satisfied: seaborn in c:\users\nitro\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: torch in c:\users\nitro\anaconda3\lib\site-packages (from timm) (2.9.0)
# Requirement already satisfied: torchvision in c:\users\nitro\anaconda3\lib\site-packages (from timm) (0.24.0)
# Requirement already satisfied: pyyaml in c:\users\nitro\anaconda3\lib\site-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in c:\users\nitro\anaconda3\lib\site-packages (from timm) (0.35.3)
# Requirement already satisfied: safetensors in c:\users\nitro\anaconda3\lib\site-packages (from timm) (0.6.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\nitro\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\nitro\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\nitro\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nitro\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nitro\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nitro\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nitro\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nitro\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nitro\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nitro\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nitro\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nitro\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nitro\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\nitro\anaconda3\lib\site-packages (from pandas) (2023.3)
# INFO: pip is looking at multiple versions of opencv-python-headless to determine which version is compatible with other requirements. This could take a while.
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: colorama in c:\users\nitro\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\nitro\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: filelock in c:\users\nitro\anaconda3\lib\site-packages (from huggingface_hub->timm) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nitro\anaconda3\lib\site-packages (from huggingface_hub->timm) (2023.10.0)
# Requirement already satisfied: requests in c:\users\nitro\anaconda3\lib\site-packages (from huggingface_hub->timm) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\nitro\anaconda3\lib\site-packages (from huggingface_hub->timm) (4.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nitro\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nitro\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nitro\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nitro\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2024.2.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\nitro\anaconda3\lib\site-packages (from torch->timm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\nitro\anaconda3\lib\site-packages (from torch->timm) (3.1)
# Requirement already satisfied: jinja2 in c:\users\nitro\anaconda3\lib\site-packages (from torch->timm) (3.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nitro\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nitro\anaconda3\lib\site-packages (from jinja2->torch->timm) (2.1.3)
# Downloading opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl (39.4 MB)
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#    - -------------------------------------- 1.8/39.4 MB 8.4 MB/s eta 0:00:05
#    -- ------------------------------------- 2.1/39.4 MB 6.5 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/39.4 MB 4.0 MB/s eta 0:00:10
#    --- ------------------------------------ 3.9/39.4 MB 4.4 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.7/39.4 MB 4.3 MB/s eta 0:00:09
#    ------ --------------------------------- 6.3/39.4 MB 4.9 MB/s eta 0:00:07
#    -------- ------------------------------- 8.4/39.4 MB 5.5 MB/s eta 0:00:06
#    --------- ------------------------------ 9.2/39.4 MB 5.4 MB/s eta 0:00:06
#    --------- ------------------------------ 9.7/39.4 MB 5.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 11.5/39.4 MB 5.3 MB/s eta 0:00:06
#    ------------- -------------------------- 12.8/39.4 MB 5.5 MB/s eta 0:00:05
#    -------------- ------------------------- 14.2/39.4 MB 5.5 MB/s eta 0:00:05
#    --------------- ------------------------ 15.2/39.4 MB 5.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.3/39.4 MB 5.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 16.8/39.4 MB 5.3 MB/s eta 0:00:05
#    ------------------- -------------------- 18.9/39.4 MB 5.5 MB/s eta 0:00:04
#    --------------------- ------------------ 20.7/39.4 MB 5.7 MB/s eta 0:00:04
#    ----------------------- ---------------- 22.8/39.4 MB 6.0 MB/s eta 0:00:03
#    ------------------------- -------------- 24.6/39.4 MB 6.1 MB/s eta 0:00:03
#    -------------------------- ------------- 26.5/39.4 MB 6.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 27.8/39.4 MB 6.2 MB/s eta 0:00:02
#    ------------------------------ --------- 30.1/39.4 MB 6.4 MB/s eta 0:00:02
#    -------------------------------- ------- 32.0/39.4 MB 6.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.6/39.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 34.3/39.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/39.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 37.2/39.4 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.4 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 39.4/39.4 MB 6.4 MB/s  0:00:06
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.11.0.86
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Installed pytorch-grad-cam.
# ERROR: Could not find a version that satisfies the requirement pytorch-grad-cam (from versions: none)
# ERROR: No matching distribution found for pytorch-grad-cam

# %%
import os, glob, random, shutil, pathlib
from collections import Counter
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm

import torch, torch.nn as nn
from torch.utils.data import DataLoader, WeightedRandomSampler
from torchvision import datasets, transforms
import timm

from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Try Grad-CAM; fall back to torchcam if needed
HAS_PTCAM = False
HAS_TORCHCAM = False
try:
    from pytorch_grad_cam import GradCAM
    from pytorch_grad_cam.utils.image import show_cam_on_image
    HAS_PTCAM = True
    print("Using pytorch-grad-cam.")
except Exception as e:
    try:
        from torchcam.methods import GradCAM as TorchGradCAM
        HAS_TORCHCAM = True
        print("Using torchcam fallback.")
    except Exception as ee:
        print("No CAM library available; CAM cell will be skipped.")

# Reproducibility & training config
SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)

IMG_SIZE    = 224
BATCH_SIZE  = 32
EPOCHS      = 20
LR          = 3e-4
CONF_THRESH = 0.6
DEVICE      = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)
# Out:
# No CAM library available; CAM cell will be skipped.
# Device: cpu

# %%
# Example: r"C:\Users\Neha - Personal\Desktop\skin-dermotology\dataset"
LOCAL_ROOT = r"C:\Users\Nitro\OneDrive\Desktop\skin-dermotology\dataset"

META_CSV = os.path.join(LOCAL_ROOT, "HAM10000_metadata.csv")

def find_dir_case_insensitive(root, name):
    for d in os.listdir(root):
        if d.lower() == name.lower() and os.path.isdir(os.path.join(root, d)):
            return os.path.join(root, d)
    return None

IMG_DIRS = [
    find_dir_case_insensitive(LOCAL_ROOT, "HAM10000_images_part_1"),
    find_dir_case_insensitive(LOCAL_ROOT, "HAM10000_images_part_2"),
]

assert os.path.exists(META_CSV), f"Missing: {META_CSV}"
for d in IMG_DIRS:
    assert d and os.path.isdir(d), f"Missing images folder: {d}"

print("Meta:", META_CSV)
print("Part1:", IMG_DIRS[0])
print("Part2:", IMG_DIRS[1])
# Out:
# Meta: C:\Users\Nitro\OneDrive\Desktop\skin-dermotology\dataset\HAM10000_metadata.csv
# Part1: C:\Users\Nitro\OneDrive\Desktop\skin-dermotology\dataset\HAM10000_images_part_1
# Part2: C:\Users\Nitro\OneDrive\Desktop\skin-dermotology\dataset\HAM10000_images_part_2

# %%
OUT_SPLIT = "data/split"   # will be created
CLASSES = ["akiec","bcc","bkl","df","mel","nv","vasc"]

# create folder tree
for split in ["train","val","test"]:
    for c in CLASSES:
        pathlib.Path(os.path.join(OUT_SPLIT, split, c)).mkdir(parents=True, exist_ok=True)

meta = pd.read_csv(META_CSV)
meta = meta[meta["dx"].isin(CLASSES)].copy()

def path_for(img_id: str):
    name = img_id + ".jpg"
    for d in IMG_DIRS:
        p = os.path.join(d, name)
        if os.path.exists(p): return p
    return None

meta["img_path"] = meta["image_id"].apply(path_for)
missing = int(meta["img_path"].isna().sum())
if missing:
    print(f"Warning: {missing} missing images; dropping.")
    meta = meta.dropna(subset=["img_path"])

# patient/lesion-wise split
lesions = meta["lesion_id"].dropna().unique().tolist()
random.shuffle(lesions)
n = len(lesions)
train_ids = set(lesions[:int(0.70*n)])
val_ids   = set(lesions[int(0.70*n):int(0.85*n)])
test_ids  = set(lesions[int(0.85*n):])

def which_split(lid):
    return "train" if lid in train_ids else ("val" if lid in val_ids else "test")

meta["split"] = meta["lesion_id"].apply(which_split)

# copy files
for _, r in tqdm(meta.iterrows(), total=len(meta), desc="Copying to data/split"):
    dst = os.path.join(OUT_SPLIT, r["split"], r["dx"], os.path.basename(r["img_path"]))
    if not os.path.exists(dst):
        shutil.copy2(r["img_path"], dst)

print(meta["split"].value_counts())
print("Class counts:\n", meta["dx"].value_counts())
# Out:
# Copying to data/split: 100%|██████████| 10015/10015 [46:21<00:00,  3.60it/s]
# split
# train    7018
# val      1512
# test     1485
# Name: count, dtype: int64
# Class counts:
#  dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64
